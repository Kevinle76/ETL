# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ## Extract Diversity_CSV into DataFrames

# %%
divers = "Resources/diversityindex.csv"

# %%
divers_df=pd.read_csv(divers)

# %%
divers_df.head()
# Out:
#                          Location  Diversity-Index  \
# 0  Aleutians West Census Area, AK         0.769346
# 1               Queens County, NY         0.742224
# 2                 Maui County, HI         0.740757
# 3              Alameda County, CA         0.740399
# 4      Aleutians East Borough, AK         0.738867
#
#    Black or African American alone, percent, 2013  \
# 0                                             7.4
# 1                                            20.9
# 2                                             0.8
# 3                                            12.4
# 4                                             7.7
#
#    American Indian and Alaska Native alone, percent, 2013  \
# 0                                               13.8
# 1                                                1.3
# 2                                                0.6
# 3                                                1.2
# 4                                               21.8
#
# ...

# %% [markdown]
# ## Transform Diversity DataFrame

# %%
divers_df['County'],divers_df['State']=divers_df['Location'].str.rsplit(', ').str
# Out:
# C:\Users\KHANHL~1.BOD\AppData\Local\Temp/ipykernel_10592/680200710.py:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   divers_df['County'],divers_df['State']=divers_df['Location'].str.rsplit(', ').str

# %%
divers_df.head()
# Out:
#                          Location  Diversity-Index  \
# 0  Aleutians West Census Area, AK         0.769346
# 1               Queens County, NY         0.742224
# 2                 Maui County, HI         0.740757
# 3              Alameda County, CA         0.740399
# 4      Aleutians East Borough, AK         0.738867
#
#    Black or African American alone, percent, 2013  \
# 0                                             7.4
# 1                                            20.9
# 2                                             0.8
# 3                                            12.4
# 4                                             7.7
#
#    American Indian and Alaska Native alone, percent, 2013  \
# 0                                               13.8
# 1                                                1.3
# 2                                                0.6
# 3                                                1.2
# 4                                               21.8
#
# ...

# %%
divers_df_data = pd.DataFrame({
        'Diver_index':divers_df.groupby(['Location','County','State'])['Diversity-Index'].mean(),
        'Black':divers_df.groupby(['Location','County','State'])['Black or African American alone, percent, 2013'].mean(),
        'American':divers_df.groupby(['Location','County','State'])['American Indian and Alaska Native alone, percent, 2013'].mean(),
        'Asian':divers_df.groupby(['Location','County','State'])['Asian alone, percent, 2013'].mean(),
        'Hawaian':divers_df.groupby(['Location','County', 'State'])['Native Hawaiian and Other Pacific Islander alone, percent,'].mean(),
        'Two or more races':divers_df.groupby(['Location','County', 'State'])['Two or More Races, percent, 2013'].mean(),
        'Hispanic':divers_df.groupby(['Location','County', 'State'])['Hispanic or Latino, percent, 2013'].mean(),
        'White':divers_df.groupby(['Location','County', 'State'])['White alone, not Hispanic or Latino, percent, 2013'].mean()
    
})

# %%
divers_df_data.head()
# Out:
#                                              Diver_index  Black  American  \
# Location             County           State
# Abbeville County, SC Abbeville County SC        0.445417   28.2       0.3
# Acadia Parish, LA    Acadia Parish    LA        0.355956   18.3       0.3
# Accomack County, VA  Accomack County  VA        0.539878   28.0       0.6
# Ada County, ID       Ada County       ID        0.256622    1.3       0.8
# Adair County, IA     Adair County     IA        0.054921    0.2       0.1
#
#                                              Asian  Hawaian  \
# Location             County           State
# Abbeville County, SC Abbeville County SC       0.4      0.0
# Acadia Parish, LA    Acadia Parish    LA       0.4      0.0
# Accomack County, VA  Accomack County  VA       0.6      0.2
# Ada County, ID       Ada County       ID       2.6      0.2
# Adair County, IA     Adair County     IA       0.4      0.0
#
# ...

# %% [markdown]
# ## Extract UnEmployment_CSV into DataFrames

# %%
unemp_df=pd.read_csv("Resources/output.csv")

# %%
unemp_df.head()
# Out:
#    Year     Month        State         County  Rate
# 0  2015  February  Mississippi  Newton County   6.1
# 1  2015  February  Mississippi  Panola County   9.4
# 2  2015  February  Mississippi  Monroe County   7.9
# 3  2015  February  Mississippi   Hinds County   6.1
# 4  2015  February  Mississippi  Kemper County  10.6

# %% [markdown]
# ## Transform UnEmployment DataFrame

# %%
unemp_df = unemp_df[['State','County','Rate']].copy()
unemp_df.head()
# Out:
#          State         County  Rate
# 0  Mississippi  Newton County   6.1
# 1  Mississippi  Panola County   9.4
# 2  Mississippi  Monroe County   7.9
# 3  Mississippi   Hinds County   6.1
# 4  Mississippi  Kemper County  10.6

# %% [markdown]
# ## Transform County DataFrame

# %%
state_st = {
        'Alabama': 'AL',
   'Alaska': 'AK',
   'Arizona': 'AZ',
   'Arkansas': 'AR',
   'California': 'CA',
   'Colorado': 'CO',
   'Connecticut': 'CT',
   'Delaware': 'DE',
   'Florida': 'FL',
   'Georgia': 'GA',
   'Hawaii': 'HI',
   'Idaho': 'ID',
   'Illinois': 'IL',
   'Indiana': 'IN',
   'Iowa': 'IA',
   'Kansas': 'KS',
   'Kentucky': 'KY',
   'Louisiana': 'LA',
   'Maine': 'ME',
   'Maryland': 'MD',
   'Massachusetts': 'MA',
   'Michigan': 'MI',
   'Minnesota': 'MN',
   'Mississippi': 'MS',
   'Missouri': 'MO',
   'Montana': 'MT',
   'Nebraska': 'NE',
   'Nevada': 'NV',
   'New Hampshire': 'NH',
   'New Jersey': 'NJ',
   'New Mexico': 'NM',
   'New York': 'NY',
   'North Carolina': 'NC',
   'North Dakota': 'ND',
   'Ohio': 'OH',
   'Oklahoma': 'OK',
   'Oregon': 'OR',
   'Pennsylvania': 'PA',
   'Rhode Island': 'RI',
   'South Carolina': 'SC',
   'South Dakota': 'SD',
   'Tennessee': 'TN',
   'Texas': 'TX',
   'Utah': 'UT',
   'Vermont': 'VT',
   'Virginia': 'VA',
   'Washington': 'WA',
   'West Virginia': 'WV',
   'Wisconsin': 'WI',
   'Wyoming': 'WY',

}

# %%
for key,value in state_st.items():
        unemp_df.loc[unemp_df['State']==key,'State']=value

# %%
unemp_df
# Out:
#        State              County  Rate
# 0         MS       Newton County   6.1
# 1         MS       Panola County   9.4
# 2         MS       Monroe County   7.9
# 3         MS        Hinds County   6.1
# 4         MS       Kemper County  10.6
# ...      ...                 ...   ...
# 885543    ME     Somerset County  10.5
# 885544    ME       Oxford County  10.5
# 885545    ME         Knox County   7.5
# 885546    ME  Piscataquis County  11.3
# 885547    ME    Aroostook County   9.0
#
# [885548 rows x 3 columns]

# %%
unemp_df_new=pd.DataFrame({'Unemp_rate':unemp_df.groupby(['State','County'])['Rate'].mean()})

# %%
unemp_df_new
# Out:
#                          Unemp_rate
# State County
# AL    Autauga County       5.417284
#       Baldwin County       5.364198
#       Barbour County       8.460185
#       Bibb County          7.684877
#       Blount County        5.164506
# ...                             ...
# WY    Sweetwater County    4.749691
#       Teton County         3.645062
#       Uinta County         5.538580
#       Washakie County      4.995062
#       Weston County        4.448765
#
# [2885 rows x 1 columns]

# %%
unemp_df['Location'] = unemp_df['County'] + ', '+ unemp_df['State']

# %%
unemp_df.head()
# Out:
#   State         County  Rate           Location
# 0    MS  Newton County   6.1  Newton County, MS
# 1    MS  Panola County   9.4  Panola County, MS
# 2    MS  Monroe County   7.9  Monroe County, MS
# 3    MS   Hinds County   6.1   Hinds County, MS
# 4    MS  Kemper County  10.6  Kemper County, MS

# %%
import pandas as pd
import json
import time
from faker import Factory,Faker
import numpy as np

# %%
# with open ('D:/GT-VIRT-DATA-PT-03-2022-U-LOL/Project-2/Resources/result.json') as f:
#     data=json.load(f)

# %%
# for i in range(0, len(data)):
#         print(data[i])

# %%
# obj=pd.read_json('D:/GT-VIRT-DATA-PT-03-2022-U-LOL/Project-2/Resources/result.json', orient='values')

# %%
# df=pd.read_json('D:/GT-VIRT-DATA-PT-03-2022-U-LOL/Project-2/Resources/result.json')
# bn = pd.DataFrame(df.features.values.tolist())['candidate']
# # pd.DataFrame.from_records(bn).head()

# %%
# import pandas as pd
# DataFrame = pd.read_json('D:/GT-VIRT-DATA-PT-03-2022-U-LOL/Project-2/Resources/result.json')
# DataFrame.to_csv('D:/GT-VIRT-DATA-PT-03-2022-U-LOL/Project-2/Resources/result2.csv')

# %%
unem_csv = "D:/GT-VIRT-DATA-PT-03-2022-U-LOL/Project-2/Resources/result2.csv"

# %%
unem_csv_df=pd.read_csv(unem_csv)

# %%
unem_csv_df.head()

# %% [markdown]
# ## Extract Median Income_CSV into DataFrames

# %%
inco =  "Resources/kaggle_income.csv"

# %%
inco_df=pd.read_csv(inco,engine='python',encoding='latin1')

# %%
inco_df.head()
# Out:
#         id  State_Code State_Name State_ab          County            City  \
# 0  1011000           1    Alabama       AL   Mobile County       Chickasaw
# 1  1011010           1    Alabama       AL  Barbour County      Louisville
# 2  1011020           1    Alabama       AL   Shelby County      Columbiana
# 3  1011030           1    Alabama       AL   Mobile County         Satsuma
# 4  1011040           1    Alabama       AL   Mobile County  Dauphin Island
#
#              Place  Type Primary  Zip_Code Area_Code     ALand     AWater  \
# 0   Chickasaw city  City   place     36611       251  10894952     909156
# 1        Clio city  City   place     36048       334  26070325      23254
# 2  Columbiana city  City   place     35051       205  44835274     261034
# 3      Creola city  City   place     36572       251  36878729    2374530
# 4   Dauphin Island  Town   place     36528       251  16204185  413605152
#
#          Lat        Lon   Mean  Median  Stdev        sum_w
# ...

# %% [markdown]
# ## Transform Median Income DataFrame

# %%
inco_df_drp1 = inco_df.drop(['id','State_Code', 'State_Name','City','Place','Type','Primary','Zip_Code','Area_Code', 'ALand','AWater','Lat', 'Lon', 'Median', 'Stdev', 'sum_w'], axis=1)

# %%
inco_df_drp1.head()
# Out:
#   State_ab          County   Mean
# 0       AL   Mobile County  38773
# 1       AL  Barbour County  37725
# 2       AL   Shelby County  54606
# 3       AL   Mobile County  63919
# 4       AL   Mobile County  77948

# %%
median_inco =  "Resources/2015 Median income by County.csv"

# %%
median_inco_df=pd.read_csv(median_inco)

# %%
median_inco_df.head()
# Out:
#               County-State          County  Population  \
# 0  Autauga County, Alabama  Autauga County       55221
# 1  Baldwin County, Alabama  Baldwin County      195121
# 2  Barbour County, Alabama  Barbour County       26932
# 3     Bibb County, Alabama     Bibb County       22604
# 4   Blount County, Alabama   Blount County       57710
#
#    Median household income State Code    State
# 0                  51281.0         AL  Alabama
# 1                  50254.0         AL  Alabama
# 2                  32964.0         AL  Alabama
# 3                  38678.0         AL  Alabama
# 4                  45813.0         AL  Alabama

# %%
median_inco_df_new=median_inco_df.drop(['County-State','State'], axis=1)

# %%
median_inco_df_new
# Out:
#                    County  Population  Median household income State Code
# 0          Autauga County       55221                  51281.0         AL
# 1          Baldwin County      195121                  50254.0         AL
# 2          Barbour County       26932                  32964.0         AL
# 3             Bibb County       22604                  38678.0         AL
# 4           Blount County       57710                  45813.0         AL
# ...                   ...         ...                      ...        ...
# 3215  Vega Baja Municipio       56858                  16948.0         WY
# 3216    Vieques Municipio        9130                  18104.0         WY
# 3217   Villalba Municipio       24685                  17818.0         WY
# 3218    Yabucoa Municipio       36279                  15627.0         WY
# 3219      Yauco Municipio       39474                  14708.0         WY
#
# [3220 rows x 4 columns]

# %%
median_inco_df_new1=median_inco_df_new.rename(columns={'State Code':'State'})

# %%
median_inco_df_new1
# Out:
#                    County  Population  Median household income State
# 0          Autauga County       55221                  51281.0    AL
# 1          Baldwin County      195121                  50254.0    AL
# 2          Barbour County       26932                  32964.0    AL
# 3             Bibb County       22604                  38678.0    AL
# 4           Blount County       57710                  45813.0    AL
# ...                   ...         ...                      ...   ...
# 3215  Vega Baja Municipio       56858                  16948.0    WY
# 3216    Vieques Municipio        9130                  18104.0    WY
# 3217   Villalba Municipio       24685                  17818.0    WY
# 3218    Yabucoa Municipio       36279                  15627.0    WY
# 3219      Yauco Municipio       39474                  14708.0    WY
#
# [3220 rows x 4 columns]

# %%
median_inco_df_new1['Location'] = median_inco_df_new1['County'] + ', '+median_inco_df_new1['State']

# %%
median_inco_df_new1.head()
# Out:
#            County  Population  Median household income State  \
# 0  Autauga County       55221                  51281.0    AL
# 1  Baldwin County      195121                  50254.0    AL
# 2  Barbour County       26932                  32964.0    AL
# 3     Bibb County       22604                  38678.0    AL
# 4   Blount County       57710                  45813.0    AL
#
#              Location
# 0  Autauga County, AL
# 1  Baldwin County, AL
# 2  Barbour County, AL
# 3     Bibb County, AL
# 4   Blount County, AL

# %%
median_inco_df_new2=pd.DataFrame({'Median household income':median_inco_df_new1.groupby(['State','County'])['Median household income'].mean(),
                                       'Population':median_inco_df_new1.groupby(['State','County'])['Population'].sum()      
})

# %%
median_inco_df_new2
# Out:
#                                   Median household income  Population
# State County
# AK    Aleutians East Borough                      61518.0        3304
#       Aleutians West Census Area                  84306.0        5684
#       Anchorage Municipality                      78326.0      299107
#       Bethel Census Area                          51012.0       17776
#       Bristol Bay Borough                         79750.0         970
# ...                                                   ...         ...
# WY    Villalba Municipio                          17818.0       24685
#       Washakie County                             47652.0        8400
#       Weston County                               57738.0        7152
#       Yabucoa Municipio                           15627.0       36279
#       Yauco Municipio                             14708.0       39474
#
# [3220 rows x 2 columns]

# %% [markdown]
# ## Merge DataFrames

# %%
merged_data_1 = pd.merge( unemp_df_new,median_inco_df_new2, on=['State','County'], how='inner')

# %%
merged_data_1.head()
# Out:
#                       Unemp_rate  Median household income  Population
# State County
# AL    Autauga County    5.417284                  51281.0       55221
#       Baldwin County    5.364198                  50254.0      195121
#       Barbour County    8.460185                  32964.0       26932
#       Bibb County       7.684877                  38678.0       22604
#       Blount County     5.164506                  45813.0       57710

# %%
merged_data_2 = pd.merge(merged_data_1,divers_df_data, on=['State','County'], how='inner')

# %%
merged_data_2
# Out:
#                          Unemp_rate  Median household income  Population  \
# State County
# AL    Autauga County       5.417284                  51281.0       55221
#       Baldwin County       5.364198                  50254.0      195121
#       Barbour County       8.460185                  32964.0       26932
#       Bibb County          7.684877                  38678.0       22604
#       Blount County        5.164506                  45813.0       57710
# ...                             ...                      ...         ...
# WY    Sweetwater County    4.749691                  69022.0       44772
#       Teton County         3.645062                  75325.0       22311
#       Uinta County         5.538580                  56569.0       20930
#       Washakie County      4.995062                  47652.0        8400
#       Weston County        4.448765                  57738.0        7152
#
#                          Diver_index  Black  American  Asian  Hawaian  \
# ...

# %%
merged_data_final=merged_data_2.reset_index()

# %%
merged_data_final
# Out:
#      State             County  Unemp_rate  Median household income  \
# 0       AL     Autauga County    5.417284                  51281.0
# 1       AL     Baldwin County    5.364198                  50254.0
# 2       AL     Barbour County    8.460185                  32964.0
# 3       AL        Bibb County    7.684877                  38678.0
# 4       AL      Blount County    5.164506                  45813.0
# ...    ...                ...         ...                      ...
# 2801    WY  Sweetwater County    4.749691                  69022.0
# 2802    WY       Teton County    3.645062                  75325.0
# 2803    WY       Uinta County    5.538580                  56569.0
# 2804    WY    Washakie County    4.995062                  47652.0
# 2805    WY      Weston County    4.448765                  57738.0
#
#       Population  Diver_index  Black  American  Asian  Hawaian  \
# 0          55221     0.388898   18.4       0.5    1.1      0.1
# ...

# %% [markdown]
# ## Create database connection

# %%
import pymysql
pymysql.install_as_MySQLdb()

# %%
connection_string = "postgres:postgres@localhost:5432/ETL_db2"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# engine = create_engine("mysql://root:@localhost/ETL_db")

# %%
divers_df_data_sql = divers_df_data.rename(columns={'County':'county',
                                                    'Location':'location',
                                               'State':'state',
                                               'Diver_index':'diver_index',
                                               'Hispanic':'hispanic',
                                               'American':'american',
                                               'Hawaian':'hawaian',
                                                    'White':'white',
                                                    'Asian':'asian',
                                                    'Black':'black',
                                               'Two or more races':'two_more_races'})

# %%
unemp_df_sql=unemp_df.rename(columns={
                        'State':'state',
                        'County':'county',
                        'Rate':'rate',
                        'Location':'location'
    
})

# %%
median_inco_df_new1_sql=median_inco_df_new1.rename(columns={
                    'County':'county',
                    'Location':'location',
                    'Population':'population',
                    'Median Household Income': 'median_household_income',
                    'State': 'state'
})

# %%
# merged_final_sql

# %%
divers_df_data_sql.to_sql(name='divers', con=engine, if_exists='append', index=False)

# %%
unemp_df_sql.to_sql(name='unemp', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1750                 if not evt_handled:
# -> 1751                     self.dialect.do_executemany(
#    1752                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     961             xtras = self._psycopg2_extras()
# --> 962             context._psycopg2_fetched_rows = xtras.execute_values(
#     963                 cursor,
#
# ~\anaconda3\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1269         parts[-1:] = post
# ...

# %%
median_inco_df_new1_sql.to_sql(name='inco', con=engine, if_exists='append', index=False)
