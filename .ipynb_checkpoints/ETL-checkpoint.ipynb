# %%
import pandas as pd

# %%
diversity_csv = "Resources/diversityindex.csv"

# %%
diversity_df=pd.read_csv(diversity_csv)

# %%
diversity_df.head()
# Out:
#                          Location  Diversity-Index  \
# 0  Aleutians West Census Area, AK         0.769346
# 1               Queens County, NY         0.742224
# 2                 Maui County, HI         0.740757
# 3              Alameda County, CA         0.740399
# 4      Aleutians East Borough, AK         0.738867
#
#    Black or African American alone, percent, 2013  \
# 0                                             7.4
# 1                                            20.9
# 2                                             0.8
# 3                                            12.4
# 4                                             7.7
#
#    American Indian and Alaska Native alone, percent, 2013  \
# 0                                               13.8
# 1                                                1.3
# 2                                                0.6
# 3                                                1.2
# 4                                               21.8
#
# ...

# %%
new_df=diversity_df

# %%
new_df['County'],new_df['State']=diversity_df['Location'].str.rsplit(', ').str
# Out:
# C:\Users\KHANHL~1.BOD\AppData\Local\Temp/ipykernel_16348/2737681682.py:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   new_df['County'],new_df['State']=diversity_df['Location'].str.rsplit(', ').str

# %%
new_df.head()
# Out:
#                          Location  Diversity-Index  \
# 0  Aleutians West Census Area, AK         0.769346
# 1               Queens County, NY         0.742224
# 2                 Maui County, HI         0.740757
# 3              Alameda County, CA         0.740399
# 4      Aleutians East Borough, AK         0.738867
#
#    Black or African American alone, percent, 2013  \
# 0                                             7.4
# 1                                            20.9
# 2                                             0.8
# 3                                            12.4
# 4                                             7.7
#
#    American Indian and Alaska Native alone, percent, 2013  \
# 0                                               13.8
# 1                                                1.3
# 2                                                0.6
# 3                                                1.2
# 4                                               21.8
#
# ...

# %%
pd.DataFrame({
        'Diver_index':new_df.groupby(['County','State'])['Diversity-Index'].mean(),
        'Black':new_df.groupby(['County','State'])['Black or African American alone, percent, 2013'].mean(),
        'American':new_df.groupby(['County','State'])['American Indian and Alaska Native alone, percent, 2013'].mean(),
        'Asian':new_df.groupby(['County','State'])['Asian alone, percent, 2013'].mean(),
        'Hawaiann':new_df.groupby(['County', 'State'])['Native Hawaiian and Other Pacific Islander alone, percent,'].mean(),
        'Two or more races':new_df.groupby(['County', 'State'])['Two or More Races, percent, 2013'].mean(),
        'Hispanic':new_df.groupby(['County', 'State'])['Hispanic or Latino, percent, 2013'].mean(),
        'White':new_df.groupby(['County', 'State'])['White alone, not Hispanic or Latino, percent, 2013'].mean()
    
})
# Out:
#                         Diver_index  Black  American  Asian  Hawaiann  \
# County           State
# Abbeville County SC        0.445417   28.2       0.3    0.4       0.0
# Acadia Parish    LA        0.355956   18.3       0.3    0.4       0.0
# Accomack County  VA        0.539878   28.0       0.6    0.6       0.2
# Ada County       ID        0.256622    1.3       0.8    2.6       0.2
# Adair County     IA        0.054921    0.2       0.1    0.4       0.0
# ...                             ...    ...       ...    ...       ...
# Yuma County      AZ        0.512612    2.7       2.2    1.5       0.2
#                  CO        0.361809    0.3       0.9    0.4       0.2
# Zapata County    TX        0.122362    0.5       0.4    0.2       0.0
# Zavala County    TX        0.132587    1.2       0.9    0.1       0.1
# Ziebach County   SD        0.427673    0.4      71.6    0.3       0.0
#
#                         Two or more races  Hispanic  White
# County           State
# ...

# %%
unemp_df=pd.read_csv("Resources/output.csv")

# %%
unemp_df.head()
# Out:
#    Year     Month        State         County  Rate
# 0  2015  February  Mississippi  Newton County   6.1
# 1  2015  February  Mississippi  Panola County   9.4
# 2  2015  February  Mississippi  Monroe County   7.9
# 3  2015  February  Mississippi   Hinds County   6.1
# 4  2015  February  Mississippi  Kemper County  10.6

# %%
unemp_df = unemp_df[['State','County','Rate']].copy()
unemp_df.head()
# Out:
#          State         County  Rate
# 0  Mississippi  Newton County   6.1
# 1  Mississippi  Panola County   9.4
# 2  Mississippi  Monroe County   7.9
# 3  Mississippi   Hinds County   6.1
# 4  Mississippi  Kemper County  10.6

# %%
state_short = {
        'Alabama': 'AL',
   'Alaska': 'AK',
   'Arizona': 'AZ',
   'Arkansas': 'AR',
   'California': 'CA',
   'Colorado': 'CO',
   'Connecticut': 'CT',
   'Delaware': 'DE',
   'Florida': 'FL',
   'Georgia': 'GA',
   'Hawaii': 'HI',
   'Idaho': 'ID',
   'Illinois': 'IL',
   'Indiana': 'IN',
   'Iowa': 'IA',
   'Kansas': 'KS',
   'Kentucky': 'KY',
   'Louisiana': 'LA',
   'Maine': 'ME',
   'Maryland': 'MD',
   'Massachusetts': 'MA',
   'Michigan': 'MI',
   'Minnesota': 'MN',
   'Mississippi': 'MS',
   'Missouri': 'MO',
   'Montana': 'MT',
   'Nebraska': 'NE',
   'Nevada': 'NV',
   'New Hampshire': 'NH',
   'New Jersey': 'NJ',
   'New Mexico': 'NM',
   'New York': 'NY',
   'North Carolina': 'NC',
   'North Dakota': 'ND',
   'Ohio': 'OH',
   'Oklahoma': 'OK',
   'Oregon': 'OR',
   'Pennsylvania': 'PA',
   'Rhode Island': 'RI',
   'South Carolina': 'SC',
   'South Dakota': 'SD',
   'Tennessee': 'TN',
   'Texas': 'TX',
   'Utah': 'UT',
   'Vermont': 'VT',
   'Virginia': 'VA',
   'Washington': 'WA',
   'West Virginia': 'WV',
   'Wisconsin': 'WI',
   'Wyoming': 'WY',

}

# %%
for key,value in state_short.items():
        unemp_df.loc[unemp_df['State']==key,'State']=value

# %%
unemp_df
# Out:
#        State              County  Rate
# 0         MS       Newton County   6.1
# 1         MS       Panola County   9.4
# 2         MS       Monroe County   7.9
# 3         MS        Hinds County   6.1
# 4         MS       Kemper County  10.6
# ...      ...                 ...   ...
# 885543    ME     Somerset County  10.5
# 885544    ME       Oxford County  10.5
# 885545    ME         Knox County   7.5
# 885546    ME  Piscataquis County  11.3
# 885547    ME    Aroostook County   9.0
#
# [885548 rows x 3 columns]

# %%
unemp_df_new=pd.DataFrame({'Unemp_rate':unemp_df.groupby(['State','County'])['Rate'].mean()})

# %%
unemp_df_new
# Out:
#                          Unemp_rate
# State County
# AL    Autauga County       5.417284
#       Baldwin County       5.364198
#       Barbour County       8.460185
#       Bibb County          7.684877
#       Blount County        5.164506
# ...                             ...
# WY    Sweetwater County    4.749691
#       Teton County         3.645062
#       Uinta County         5.538580
#       Washakie County      4.995062
#       Weston County        4.448765
#
# [2885 rows x 1 columns]

# %%
import pandas as pd
import json
import time
from faker import Factory,Faker
import numpy as np

# %%
# with open ('D:/GT-VIRT-DATA-PT-03-2022-U-LOL/Project-2/Resources/result.json') as f:
#     data=json.load(f)

# %%
# for i in range(0, len(data)):
#         print(data[i])

# %%
# obj=pd.read_json('D:/GT-VIRT-DATA-PT-03-2022-U-LOL/Project-2/Resources/result.json', orient='values')

# %%
# df=pd.read_json('D:/GT-VIRT-DATA-PT-03-2022-U-LOL/Project-2/Resources/result.json')
# bn = pd.DataFrame(df.features.values.tolist())['candidate']
# # pd.DataFrame.from_records(bn).head()

# %%
import pandas as pd
DataFrame = pd.read_json('D:/GT-VIRT-DATA-PT-03-2022-U-LOL/Project-2/Resources/result.json')
DataFrame.to_csv('D:/GT-VIRT-DATA-PT-03-2022-U-LOL/Project-2/Resources/result2.csv')

# %%
unem_csv = "D:/GT-VIRT-DATA-PT-03-2022-U-LOL/Project-2/Resources/result2.csv"

# %%
unem_csv_df=pd.read_csv(unem_csv)

# %%
unem_csv_df.head()
# Out:
#   Unnamed: 0                                               1990  \
# 0     Annual  {'Alabama': {'12 Month Net Change': {}, 'Unemp...
# 1      April  {'Alabama': {'12 Month Net Change': {}, 'Unemp...
# 2     August  {'Alabama': {'12 Month Net Change': {}, 'Unemp...
# 3   December  {'Alabama': {'12 Month Net Change': {}, 'Unemp...
# 4   February  {'Alabama': {'12 Month Net Change': {}, 'Unemp...
#
#                                                 1991  \
# 0  {'Alabama': {'12 Month Net Change': {}, 'Unemp...
# 1  {'Alabama': {'12 Month Net Change': {}, 'Unemp...
# 2  {'Alabama': {'12 Month Net Change': {}, 'Unemp...
# 3  {'Alabama': {'12 Month Net Change': {}, 'Unemp...
# 4  {'Alabama': {'12 Month Net Change': {}, 'Unemp...
#
#                                                 1992  \
# 0  {'Alabama': {'12 Month Net Change': {}, 'Unemp...
# 1  {'Alabama': {'12 Month Net Change': {}, 'Unemp...
# 2  {'Alabama': {'12 Month Net Change': {}, 'Unemp...
# ...
